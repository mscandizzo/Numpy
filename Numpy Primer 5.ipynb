# %% [markdown]
# ### Numpy Primer
# ----------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline
import random

# %% [markdown]
# ### OLS Regression
#
# NumPy provides two convenience functions to implement ordinary least squares regression. They are `np.polyfit` and `np.polyval`.

# %%
a = 100 + 5 * np.random.standard_normal((2, 8))
print(a.shape)
a
# Out:
# (2, 8)
# array([[102.14105551,  93.7843156 , 103.23726015,  89.06630428,
#         110.59302992, 102.70553152, 102.89418062, 102.67871669],
#        [ 97.27188086, 107.37582581, 102.0923096 ,  96.78944592,
#          91.77537689, 102.08080414,  92.59897379,  94.26585191]])

# %%
reg1 = np.polyfit(a[0],a[1],1) # Linear regression
reg1
# Out:
# array([ -0.37780091, 136.14671641])

# %%
reg2 = np.polyfit(a[0],a[1],2) # Cuadratic regression
reg2
# Out:
# array([-4.35414042e-02,  8.25476526e+00, -2.89950526e+02])

# %%
reg3 = np.polyfit(a[0],a[1],3) # Cubic regression
reg3
# Out:
# array([ 1.15819548e-02, -3.53904909e+00,  3.58752852e+02, -1.19644507e+04])

# %% [markdown]
# Let us plot the regression lines

# %%
plt.figure(figsize=(10, 6))
plt.plot(a[0], a[1], 'ro');
x = np.linspace(a[0].min(), a[0].max(), 100) # It creates 100 evenly distributed data points based on a[0] min to max
plt.plot(x, np.polyval(reg1, x), 'b--', label='linear') # polyval evaluates the regression result on each of the 100 data points
plt.plot(x, np.polyval(reg2, x), 'm-.', label='quadratic') # provided populating the results of each type of regression
plt.plot(x, np.polyval(reg3, x), 'g.', label='cubic')
plt.legend();

# %%
reg8 = np.polyfit(a[0], a[1], 7)  # perfect regression
reg8
# Out:
# C:\Users\maria\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RankWarning: Polyfit may be poorly conditioned
#   """Entry point for launching an IPython kernel.
# array([-5.51812420e-04,  2.75025455e-01, -4.88905740e+01,  2.52098863e+03,
#         3.11459526e+05, -5.24493656e+07,  2.86858094e+09, -5.68613014e+10])

# %%
plt.figure(figsize=(10, 6))
plt.plot(a[0], a[1], 'ro');
plt.plot(x, np.polyval(reg8, x), 'b', label='perfect')
plt.legend();
